# %% [markdown]
# ##Importação de Libs

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ##Carregamento img

# %%
img = cv2.imread("area_trello.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img.shape

plt.imshow(img)
plt.show()
